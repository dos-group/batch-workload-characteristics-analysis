# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a similar DataFrame named `data` for this example
# Prepare the data for the stacked column chart
layers_expanded = data['Layers'].str.get_dummies(sep=', ')
publication_years = data[['Year']].join(layers_expanded)

# Group by year and sum the layers
layer_counts_per_year = publication_years.groupby('Year').sum()

# Calculate percentages for annotations
layer_percentages_per_year = layer_counts_per_year.div(layer_counts_per_year.sum(axis=1), axis=0) * 100

# Plot the stacked column chart
plt.figure(figsize=(12, 8))

# Stacked bar plot
ax = layer_counts_per_year.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='tab20', edgecolor='black', zorder=2, width=0.8)

# Annotate the bars with the percentages
for i in range(layer_counts_per_year.shape[0]):
    cumulative_height = 0
    for j, layer in enumerate(layer_counts_per_year.columns):
        count = layer_counts_per_year.iloc[i, j]
        percentage = layer_percentages_per_year.iloc[i, j]
        if count > 0:
            ax.text(i, cumulative_height + count / 2, f'{percentage:.1f}%', ha='center', va='center', fontsize=18, color='black')
        cumulative_height += count

# Add grid lines
ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=1)

# Set the title and labels with increased font size
plt.xlabel('Year', fontsize=20)
plt.ylabel('Number of Publications', fontsize=20)

# Increase the font size of the legend and place it above the plot
legend = plt.legend(bbox_to_anchor=(0.5, 1.1), loc='center', fontsize=20, ncol=3, title='Layers')
legend.get_title().set_fontsize(20)  # Increase font size of legend title

# Increase the font size of tick labels
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.show()
